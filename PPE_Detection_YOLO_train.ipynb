# %% [markdown]
# **Custom dataset model training can also be done offline using any other IDE**

# %% [markdown]
# Checking GPU utilization

# %%
# !nvidia-smi
# Out:
# Wed Jan 17 13:19:23 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.7/699.7 kB 8.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %% [markdown]
# Checking to see if YOLO is working here

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 322MB/s]
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients, 165.2 GFLOPs
#
# ...
# 100% 476k/476k [00:00<00:00, 35.9MB/s]
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/bus.jpg: 640x480 5 persons, 1 bicycle, 1 bus, 129.7ms
# Speed: 14.0ms preprocess, 129.7ms inference, 1098.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# Train Custom Data for PPE detection

# %%
# !yolo task=detect mode=train model=yolov8l.pt conf=0.25 data=../content/drive/MyDrive/Datasets/ConstructionSafety/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# prompt: zip /content/runs/detect/train2 and download

# !zip -r /content/runs/detect/train2.zip /content/runs/detect/train2
files.download('/content/runs/detect/train2.zip')
# Out:
#   adding: content/runs/detect/train2/ (stored 0%)
#   adding: content/runs/detect/train2/val_batch0_pred.jpg (deflated 5%)
#   adding: content/runs/detect/train2/labels.jpg (deflated 21%)
#   adding: content/runs/detect/train2/val_batch0_labels.jpg (deflated 5%)
#   adding: content/runs/detect/train2/labels_correlogram.jpg (deflated 34%)
#   adding: content/runs/detect/train2/F1_curve.png (deflated 12%)
#   adding: content/runs/detect/train2/confusion_matrix_normalized.png (deflated 13%)
#   adding: content/runs/detect/train2/val_batch1_pred.jpg (deflated 9%)
#   adding: content/runs/detect/train2/train_batch1321.jpg (deflated 7%)
#   adding: content/runs/detect/train2/train_batch0.jpg (deflated 4%)
#   adding: content/runs/detect/train2/train_batch2.jpg (deflated 3%)
#   adding: content/runs/detect/train2/confusion_matrix.png (deflated 17%)
#   adding: content/runs/detect/train2/results.csv (deflated 84%)
#   adding: content/runs/detect/train2/train_batch1.jpg (deflated 4%)
# ...
